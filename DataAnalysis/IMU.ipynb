# %%
import pandas as pd
from pathlib import Path
import os

# %%
core_data_path = Path('/Users/riccardoconci/Local_documents/!CURRENT_RESEARCH/Personalising-Crutches/data_V2/raw')  
MIH15_IMU_trials_dir = core_data_path / 'MIH15' / '2025-10-21' / 'trials'
MIH15_IMU_trials_dir
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 core_data_path = Path('/Users/riccardoconci/Local_documents/!CURRENT_RESEARCH/Personalising-Crutches/data_V2/raw')
#       2 MIH15_IMU_trials_dir = core_data_path / 'MIH15' / '2025-10-21' / 'trials'
#       3 MIH15_IMU_trials_dir
#
# NameError: name 'Path' is not defined
